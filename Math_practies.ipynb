# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

# %%
# Expression : f (x) = 2*x +1
x = symbols("X")
f = 2*x +1
plot(f)

# %%
# here we have created parabola but its not our requirement 
# Expression : f (x) = x**2+1
x = symbols("X")
f = x**2 +1
plot(f)

# %%
from sympy.plotting import plot3d

# %%
# Expression : f(x, y) = 2x + 3y
x,y = symbols("x y")
f = 2*x + 3*y
plot3d(f)

# %%
#summations of given range of number / important topic
summation =   sum(2*i for i in range(1,6))
print(summation)
# Out:
# 30

# %%
x  = [1,2,3,4,5,6]
n= len(x)

summations =  sum(10*x[i] for i in range(n))
print(summations)
# Out:
# 210

# %% [markdown]
# Exponents Starts here

# %%
x = symbols("x")
exper = x**2/x**5
print(exper)
# Out:
# x**(-3)

# %%
exper
# Out:
# x**(-3)

# %%
#Logarithm expression 
# To find log base2 8 = x 

from math import log 

x = log(8,2)
print(x)
# Out:
# 3.0

# %%
from math import exp
p = 100
r = .20 
t = 2.0 
n = 12 

a  = p*(1+(r/n)) **(n*t)
print(a)
# Out:
# 148.69146179463576

# %%
p = 100
r = .20 
t = 2.0 
n = 365

a  = p*(1+(r/n)) **(n*t)
print(a)
# Out:
# 149.16612786515807

# %%
p = 100
r = .20 
t = 2.0 
n = 8760

a  = p*(1+(r/n)) **(n*t)
print(a)
# Out:
# 149.18178857773455

# %%
p = 100
r = .20 
t = 2.0 
n = 525600

a  = p*(1+(r/n)) **(n*t)
print(a)
# Out:
# 149.182458398811

# %%
p = 100
r = .20 
t = 2.0 
n = 12 
#Now using Eluers i.e (e)  
a  = p* exp(r*t)
print(a)
# Out:
# 149.18246976412703

# %%
from math import log

# %%
x = log(10)
print(x)
# Out:
# 2.302585092994046

# %%
x = symbols("x")
f = 1/x
result  = limit(f,x,oo)
plot(result)

# %%
print(result)
# Out:
# 0

# %%
from sympy import *

n = symbols("n")
f = ( 1+ (1/n)) ** n
result = limit( f, n, oo)

print(result)
print(result.evalf())
# Out:
# E
# 2.71828182845905

# %%
plot(f)
