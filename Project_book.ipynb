# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("default_of_credit_card_clients__courseware_version_1_21_19.xls")
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.select_dtypes(include="number").corr()
# Out:
#                             LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# LIMIT_BAL                    1.000000  0.064827  -0.182030 -0.064176
# SEX                          0.064827  1.000000   0.087350  0.063636
# EDUCATION                   -0.182030  0.087350   1.000000 -0.064907
# MARRIAGE                    -0.064176  0.063636  -0.064907  1.000000
# AGE                          0.182063  0.037687   0.242956 -0.260869
# PAY_2                       -0.294889 -0.069787   0.116157  0.019599
# PAY_3                       -0.285132 -0.067032   0.108534  0.026609
# PAY_4                       -0.267011 -0.062984   0.101424  0.025877
# PAY_5                       -0.250228 -0.059243   0.089147  0.026297
# PAY_6                       -0.236397 -0.049570   0.073598  0.024554
# BILL_AMT1                    0.291211 -0.008420   0.038102 -0.001965
# BILL_AMT2                    0.284427 -0.005958   0.033739 -0.000266
# BILL_AMT3                    0.289167 -0.000424   0.027922 -0.004106
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.nunique()
# Out:
# ID                            29687
# LIMIT_BAL                        82
# SEX                               3
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              57
# PAY_1                            12
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22510
# BILL_AMT2                     22146
# BILL_AMT3                     21822
# BILL_AMT4                     21350
# BILL_AMT5                     20831
# BILL_AMT6                     20417
# PAY_AMT1                       7890
# PAY_AMT2                       7847
# PAY_AMT3                       7463
# PAY_AMT4                       6901
# PAY_AMT5                       6857
# PAY_AMT6                       6895
# default payment next month        2
# dtype: int64

# %%
df["ID"].nunique()
# Out:
# 29687

# %%
id_count = df["ID"].value_counts()
id_count.head()
# Out:
# ID
# 7d5f3242-e1df    2
# 1b22b0ab-aba3    2
# 4cb27699-fe3f    2
# 91c69d1a-8732    2
# bf23c70b-bf12    2
# Name: count, dtype: int64

# %%
id_count.value_counts()
# Out:
# count
# 1    29374
# 2      313
# Name: count, dtype: int64

# %%
from numpy.random import default_rng
'''rg = default_rng(12345)
rand_int = rg.integers(low = 1, high = 5 , size = [100])
rand_int
# we are cerating  Boolean mask to find the number = 3 
is_equal_to_3 = rand_int == 3 
is_equal_to_3
sum(is_equal_to_3)
rand_int[is_equal_to_3]'''

# The above is the an example code how to work with the numpy lib and boolean masking
# Out:
# 'rg = default_rng(12345)\nrand_int = rg.integers(low = 1, high = 5 , size = [100])\nrand_int\n# we are cerating  Boolean mask to find the number = 3 \nis_equal_to_3 = rand_int == 3 \nis_equal_to_3\nsum(is_equal_to_3)\nrand_int[is_equal_to_3]'

# %%
dup_id = id_count ==2
dup_id
# Out:
# ID
# 7d5f3242-e1df     True
# 1b22b0ab-aba3     True
# 4cb27699-fe3f     True
# 91c69d1a-8732     True
# bf23c70b-bf12     True
#                  ...
# 5e9d04ca-53f0    False
# 891781cb-8211    False
# 8dd31d95-45cf    False
# 811730c0-898a    False
# 798fc410-45c1    False
# Name: count, Length: 29687, dtype: bool

# %%
dup_id.index[0:5]
# Out:
# Index(['7d5f3242-e1df', '1b22b0ab-aba3', '4cb27699-fe3f', '91c69d1a-8732',
#        'bf23c70b-bf12'],
#       dtype='object', name='ID')

# %%
dup = id_count.index[dup_id]
dup[:5]
# Out:
# Index(['7d5f3242-e1df', '1b22b0ab-aba3', '4cb27699-fe3f', '91c69d1a-8732',
#        'bf23c70b-bf12'],
#       dtype='object', name='ID')

# %%
dup_list  = list(dup)
lenth = len(dup_list)
lenth
# Out:
# 313

# %%
dup_list[:5]
# Out:
# ['7d5f3242-e1df',
#  '1b22b0ab-aba3',
#  '4cb27699-fe3f',
#  '91c69d1a-8732',
#  'bf23c70b-bf12']

# %%
df.loc[df["ID"].isin(dup_list[0:3]),:]
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE          PAY_1  \
# 5374   1b22b0ab-aba3      30000    2          1         2   30              0
# 5474   1b22b0ab-aba3          0    0          0         0    0              0
# 5583   7d5f3242-e1df      60000    1          1         2   22  Not available
# 5683   7d5f3242-e1df          0    0          0         0    0              0
# 11848  4cb27699-fe3f      60000    2          6         1   39             -1
# 11948  4cb27699-fe3f          0    0          0         0    0              0
#
#        PAY_2  PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 5374       0      0      0  ...      32389      33142      33999      1600
# 5474       0      0      0  ...          0          0          0         0
# 5583       0      2      0  ...      29137      29900      30069      4400
# 5683       0      0      0  ...          0          0          0         0
# ...

# %%
# we are masking the entier df which matches with zero 
df_zero_mask = df == 0 
df_zero_mask
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_1  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False   True   True
# 3      False      False  False      False     False  False   True   True
# 4      False      False  False      False     False  False  False   True
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False   True   True
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False   True   True
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
# we are masking the feature from excluding the 1st column and include all the rows
feature_zero_mask = df_zero_mask.iloc[ : , 1 :].all(axis = 1)

# %%
sum(feature_zero_mask)
# Out:
# 315

# %%
feature_zero_mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Length: 30000, dtype: bool

# %%
df_clean_1 = df.loc[~feature_zero_mask, :].copy()

# %%
df_clean_1["ID"].nunique()
# Out:
# 29685

# %%
df_clean_1.to_csv("df_clean.csv", index = False)
