# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 
import matplotlib as mpl # Additional plotting func
mpl.rcParams['figure.dpi']=400 # high resolution figure

# %%
df = pd.read_csv("df_clean_2.csv")
df.head()
# Out:
#    Unnamed: 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  \
# 0           0  798fc410-45c1      20000    2          2         1   24      2
# 1           1  8a8c8f3b-8eb4     120000    2          2         2   26     -1
# 2           2  85698822-43f5      90000    2          2         2   34      0
# 3           3  0737c11b-be42      50000    2          2         1   37      0
# 4           4  3b7f77cc-dbc0      50000    1          2         1   57     -1
#
#    PAY_2  PAY_3  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      2     -1  ...          0          0          0         0       689
# 1      2      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4      0     -1  ...      20940      19146      19131      2000     36681
#
# ...

# %%
plt.figsize=(12,8) 
df[['AGE','LIMIT_BAL']].hist()
# Out:
# array([[<Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'LIMIT_BAL'}>]], dtype=object)

# %%
df[['LIMIT_BAL','AGE']].describe()
# Out:
#            LIMIT_BAL           AGE
# count   26664.000000  26664.000000
# mean   167919.054905     35.505213
# std    129839.453081      9.227442
# min     10000.000000     21.000000
# 25%     50000.000000     28.000000
# 50%    140000.000000     34.000000
# 75%    240000.000000     41.000000
# max    800000.000000     79.000000

# %%
df["EDUCATION"].value_counts()
# Out:
# EDUCATION
# 2    12458
# 1     9412
# 3     4380
# 5      245
# 4      115
# 6       43
# 0       11
# Name: count, dtype: int64

# %%
df["EDUCATION"].replace(to_replace = [0,5,6], value = 4)
df["EDUCATION"].value_counts()
# Out:
# EDUCATION
# 2    12458
# 1     9412
# 3     4380
# 4      414
# Name: count, dtype: int64

# %%
df["MARRIAGE"].value_counts()
# Out:
# MARRIAGE
# 2    14158
# 1    12172
# 3      286
# 0       48
# Name: count, dtype: int64

# %%
df["MARRIAGE"].replace(to_replace = 0 , value = 3)
df["MARRIAGE"].value_counts()
# Out:
# MARRIAGE
# 2    14158
# 1    12172
# 3      286
# 0       48
# Name: count, dtype: int64

# %%
df.to_csv("df_clean_3.csv")
